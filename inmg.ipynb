# %%
import json
jd=open("sales.json",'a')
fd=open("stock.json",'w')
cart=[]
price=[]
trimmer={'category':'electronics','no':'1','model':'nova','cost':'1000','weight':'nil'}
airpodes={'category':'electronics','no':'2','model':'realme','cost':'1500','weight':'nil'}
mobile={'category':'electronics','no':'3','model':'moto','cost':'10000','weight':'nil'}
laptop={'category':'electronics','no':'4','model':'hp','cost':'40000','weight':'nil'}
fridge={'category':'electronics','no':'5','model':'samsung','cost':'20000','weight':'nil'}


cake={'category':'food','no':'6','model':'plain','cost':'200','weight':'500g'}
chocolate={'category':'food','no':'7','model':'snickers','cost':'50','weight':'100g'}
sweets={'category':'food','no':'8','model':'kova','cost':'100','weight':'250g'}
noodles={'category':'food','no':'9','model':'gobi','cost':'50','weight':'250g'}
icecream={'category':'food','no':'10','model':'pista','cost':'150','weight':'500g'}

oil={'category':'household','no':'11','model':'refined','cost':'150','weight':'1000g'}
dal={'category':'household','no':'12','model':'toordal','cost':'100','weight':'1000g'}
rice={'category':'household','no':'13','model':'polished','cost':'1200','weight':'25000g'}
flour={'category':'household','no':'14','model':'aata','cost':'250','weight':'5000g'}
sugar={'category':'household','no':'15','model':'small','cost':'400','weight':'10000g'}


mango={'category':'fruits and veg','no':'16','model':'bangenpalli','cost':'100','weight':'2500g'}
tomato={'category':'fruits and veg','no':'17','model':'country','cost':'50','weight':'2000g'}
apple={'category':'fruits and veg','no':'18','model':'imported','cost':'200','weight':'1000g'}
potato={'category':'fruits and veg','no':'19','model':'economy','cost':'100','weight':'3000g'}
onion={'category':'fruits and veg','no':'20','model':'large','cost':'150','weight':'5000g'}


perfume={'category':'skin care','no':'21','model':'fogg','cost':'250','weight':'500g'}
soap={'category':'skincare','no':'22','model':'cinthol','cost':'50','weight':'250g'}
paste={'category':'skincare','no':'23','model':'daburred','cost':'100','weight':'200g'}
powder={'category':'skincare','no':'24','model':'ponds','cost':'150','weight':'500g'}
shampoo={'category':'skincare','no':'25','model':'sunsilk','cost':'120','weight':'250g'}


shirt={'category':'fashion','no':'26','model':'tshirt','cost':'250','weight':'nil'}
pant={'category':'fashion','no':'27','model':'jeans','cost':'500','weight':'nil'}
glasses={'category':'fashion','no':'28','model':'cooling','cost':'350','weight':'nil'}
boxer={'category':'fashion','no':'29','model':'printed','cost':'150','weight':'nil'}
hoodie={'category':'fashion','no':'30','model':'svp','cost':'1000','weight':'nil'}

avail={1:['trimmer',3],2:['airpodes',2],3:['mobile',5],4:['laptop',4],5:['fridge',8],6:['cake',10],7:['chocolate',20],8:['sweets',5],9:['noodles',0],10:['icecream',3],11:['oil',14],12:['dal',10],13:['rice',5],14:['flour',2],15:['sugar',7],16:['mango',1],17:['tomato',5],18:['apple',0],19:['potato',3],20:['onion',4],21:['perfume',4],22:['soap',10],23:['paste',5],24:['powder',5],25:['shampoo',1],26:['shirt',5],27:['pant',6],28:['glasses',0],29:['boxer',4],30:['hoodie',1]}

def bill():
    amount=0
    for i in price:
        amount+=int(i)
    print('items you purchased are:',cart)
    print('total cost is:',amount)
    if amount>=20000:
        amount=amount*0.8
    elif amount>=10000 and amount<20000:
        amount=amount*0.9
    elif amount>=5000 and amount<10000:
        amount=amount*0.95
    else:
        print(amount)
    print('your bill after discount is:',amount)
    
    
    
a=int(input('hello!would you like to shop with us: 1.yes 2.no'))



def silly():
    b=c=d=e=f=g=h=i=0
    if a==1:
        b=int(input('in which category do you wish to shop: 1.electronics\n  2.food\n  3.household\n 4.fruits and veg\n 5.skincare\n 6.fashion'))
    else:
        print('thank you!have a nice day')
    
    

    if b==1:
        c=int(input('which product do you want? 1.trimmer\n 2.airpodes\n 3.mobile\n 4.laptop\n 5.fridge'))
    elif b==2:
        d=int(input('which product do you want? 1.cakes\n 2.chocolates\n 3.sweets\n 4.noodles\n 5.icecream '))
    elif b==3:
        e=int(input('which product do you want? 1.oil\n 2.dal\n 3.rice\n 4.flour\n 5.sugar'))
    elif b==4:
        f=int(input('which product do you want? 1.mango\n2.tomato\n3.apple\n 4.potato\n 5.onion'))
    elif b==5:
        g=int(input('which product do you want? 1.perfume\n2.soap\n3.paste\n 4.powder\n 5.shampoo'))
    elif b==6:
        h=int(input('which product do you want? 1.shirt\n2.pant\n3.glasses\n 4.boxer\n 5.hoodie'))
    elif b==0:
        pass
    else:
        print('please choose available category')
        
        
        

    if c==1 and avail[1][1]!=0:
        cart.append(trimmer)
        price.append(trimmer['cost'])
        avail[1][1]-=1
    elif c==2 and avail[2][1]!=0:
        cart.append(airpodes)
        price.append(airpodes['cost'])
        avail[2][1]-=1
    elif c==3 and avail[3][1]!=0:
        cart.append(mobile)
        price.append(mobile['cost'])
        avail[3][1]-=1
    elif c==4 and avail[4][1]!=0:
        cart.append(laptop)
        price.append(laptop['cost'])
        avail[4][1]-=1
    elif c==5 and avail[5][1]!=0:
        cart.append(fridge)
        price.append(fridge['cost'])
        avail[5][1]-=1
    elif c==0:
        pass
    else:
        print('sorry!product is not available')




    if d==1 and avail[6][1]!=0:
        cart.append(cake)
        price.append(cake['cost'])
        avail[6][1]-=1
    elif d==2 and avail[7][1]!=0:
        cart.append(chocolate)
        price.append(chocolate['cost'])
        avail[7][1]-=1
    elif d==3 and avail[8][1]!=0:
        cart.append(sweets)
        price.append(sweets['cost'])
        avail[8][1]-=1
    elif d==4 and avail[9][1]!=0:
        cart.append(noodles)
        price.append(noodles['cost'])
        avail[9][1]-=1
    elif d==5 and avail[10][1]!=0:
        cart.append(icecream)
        price.append(icecream['cost'])
        avail[10][1]-=1
    elif d==0:
        pass
    else:
        print('sorry!product is not available')
        
        
        
    if e==1 and avail[11][1]!=0:
        cart.append(oil)
        price.append(oil['cost'])
        avail[11][1]-=1
    elif e==2 and avail[12][1]!=0:
        cart.append(dal)
        price.append(dal['cost'])
        avail[12][1]-=1
    elif e==3 and avail[13][1]!=0:
        cart.append(rice)
        price.append(rice['cost'])
        avail[13][1]-=1
    elif e==4 and avail[14][1]!=0:
        cart.append(flour)
        price.append(flour['cost'])
        avail[14][1]-=1
    elif e==5 and avail[15][1]!=0:
        cart.append(sugar)
        price.append(sugar['cost'])
        avail[15][1]-=12
    elif e==0:
        pass
    else:
        print('sorry!product is not available')
        
        
        
    if f==1 and avail[16][1]!=0:
        cart.append(mango)
        price.append(mango['cost'])
        avail[16][1]-=1
    elif f==2 and avail[17][1]!=0:
        cart.append(tomato)
        price.append(tomato['cost'])
        avail[17][1]-=1
    elif f==3 and avail[18][1]!=0:
        cart.append(apple)
        price.append(apple['cost'])
        avail[18][1]-=1
    elif f==4 and avail[19][1]!=0:
        cart.append(potato)
        price.append(potato['cost'])
        avail[19][1]-=1
    elif f==5 and avail[20][1]!=0:
        cart.append(onion)
        price.append(onion['cost'])
        avail[20][1]-=1
    elif f==0:
        pass
    else:
        print('sorry!product is not available')
        
        
        
    if g==1 and avail[21][1]!=0:
        cart.append(perfume)
        price.append(perfume['cost'])
        avail[21][1]-=1
    elif g==2 and avail[22][1]!=0:
        cart.append(soap)
        price.append(soap['cost'])
        avail[22][1]-=1
    elif g==3 and avail[23][1]!=0:
        cart.append(paste)
        price.append(paste['cost'])
        avail[23][1]-=1
    elif g==4 and avail[24][1]!=0:
        cart.append(powder)
        price.append(powder['cost'])
        avail[24][1]-=1
    elif g==5 and avail[25][1]!=0:
        cart.append(shampoo)
        price.append(shampoo['cost'])
        avail[25][1]-=1
    elif g==0:
        pass
    else:
        print('sorry!product is not available')
        
        
    if h==1 and avail[26][1]!=0:
        cart.append(shirt)
        price.append(shirt['cost'])
        avail[26][1]-=1
    elif h==2 and avail[27][1]!=0:
        cart.append(pant)
        price.append(pant['cost'])
        avail[27][1]-=1
    elif h==3 and avail[28][1]!=0:
        cart.append(glasses)
        price.append(glasses['cost'])
        avail[28][1]-=1
    elif h==4 and avail[29][1]!=0:
        cart.append(boxer)
        price.append(boxer['cost'])
        avail[29][1]-=1
    elif h==5 and avail[30][1]!=0:
        cart.append(hoodie)
        price.append(hoodie['cost'])
        avail[30][1]-=1
    elif h==0:
        pass
    else:
        print('sorry!product is not available')
        
        
        
        

        
        
        
        
    print(cart)
    print(price)
    
    
    if cart!=[]:
        i=int(input('do you wish to print bill? 1.yes 2.no'))
    else:
        print('please add any product')
        
        
    if i==1:
        bill()
    elif i==0:
        pass
    else:
        silly()
    
    
            
silly() 
print('products reamaining are:')   
print(avail)
kd=json.dumps(cart)
jd.write(kd)
jd.close()
yd=json.dumps(avail)
fd.write(yd)
fd.close()
# Out:
# hello!would you like to shop with us: 1.yes 2.no1
# in which category do you wish to shop: 1.electronics
#   2.food
#   3.household
#  4.fruits and veg
#  5.skincare
#  6.fashion1
# which product do you want? 1.trimmer
#  2.airpodes
#  3.mobile
#  4.laptop
#  5.fridge3
# [{'category': 'electronics', 'no': '3', 'model': 'moto', 'cost': '10000', 'weight': 'nil'}]
# ['10000']
# do you wish to print bill? 1.yes 2.no2
# in which category do you wish to shop: 1.electronics
#   2.food
#   3.household
#  4.fruits and veg
#  5.skincare
#  6.fashion6
# which product do you want? 1.shirt
# 2.pant
# 3.glasses
#  4.boxer
#  5.hoodie5
# [{'category': 'electronics', 'no': '3', 'model': 'moto', 'cost': '10000', 'weight': 'nil'}, {'category': 'fashion', 'no': '30', 'model': 'svp', 'cost': '1000', 'weight': 'nil'}]
# ['10000', '1000']
# do you wish to print bill? 1.yes 2.no2
# in which category do you wish to shop: 1.electronics
#   2.food
#   3.household
#  4.fruits and veg
#  5.skincare
# ...
